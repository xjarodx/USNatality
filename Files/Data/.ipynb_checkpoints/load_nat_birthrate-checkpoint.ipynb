# %%
import csv
from sqlalchemy import create_engine, MetaData
from sqlalchemy import Column, Integer, String
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd
import os

# %%
# create mysql database connection
#engine = create_engine('mysql+pymysql://root:password@localhost:3306/birthrate_db', echo=False)
# create sqlite database connection
db_url = 'nat_birthrate_2013_2017.sqlite'
os.remove(db_url)
engine = create_engine(f'sqlite:///{db_url}', echo=False)
Session = sessionmaker(bind=engine)
session = Session()
metadata = MetaData(engine)
Base = declarative_base(metadata=metadata)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7ab9d920d781> in <module>()
#       3 # create sqlite database connection
#       4 db_url = 'nat_birthrate_2013_2017.sqlite'
# ----> 5 os.remove(db_url)
#       6 engine = create_engine(f'sqlite:///{db_url}', echo=False)
#       7 Session = sessionmaker(bind=engine)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'nat_birthrate_2013_2017.sqlite'

# %%
# create sqlalchemy class
class BirthRateRecord(Base):
    __tablename__ = 'national_birth_rate_2013_2017'
    
    ID = Column(Integer, primary_key=True)
    Country =  Column(String(255))
    CountryCode = Column(String(255))
    Year = Column(Integer())
    YearCode = Column(Integer())
    Birth = Column(Integer())
    TotalPopulation = Column(Integer())
    BirthRate = Column(Integer())
    AvgAgeOfMother = Column(Integer())
    AvgLMPGestAge = Column(Integer())

# %%
# initialize tables in database
metadata.create_all()

# %%
# read csv
path = './RawNatalData/Natality_BirthRates_2013_2017.csv'

with open(path, 'r') as csvfile:
    # remove old sqlite file
    data = csv.reader(csvfile);
    header = next(data)
    cleaned = filter(lambda r: r[0] != '' and r[1] != '', data)
    for row in cleaned:
        try:
            record = BirthRateRecord( \
                ID = row[0], \
                Country =  row[1], \
                CountryCode = row[2], \
                Year = row[3], \
                YearCode = row[4], \
                Birth = row[5], \
                TotalPopulation = row[6], \
                BirthRate = row[7], \
                AvgAgeOfMother = row[7], \
                AvgLMPGestAge = row[8]
            )
            session.add(record)
        except ex:
            print(list(row))
    session.commit()

# %%
# check data in db
query = session.query(BirthRateRecord)

df = pd.read_sql(query.statement, query.session.bind)

df
# Out:
#         ID                    Country CountryCode  Year  YearCode  Birth  \
# 0        1         Baldwin County, AL        1003  2013      2013   2160
# 1        2         Baldwin County, AL        1003  2014      2014   2244
# 2        3         Baldwin County, AL        1003  2015      2015   2344
# 3        4         Baldwin County, AL        1003  2016      2016   2247
# 4        5         Baldwin County, AL        1003  2017      2017   2322
# 5        6         Calhoun County, AL        1015  2013      2013   1347
# 6        7         Calhoun County, AL        1015  2014      2014   1291
# 7        8         Calhoun County, AL        1015  2015      2015   1400
# 8        9         Calhoun County, AL        1015  2016      2016   1357
# 9       10         Calhoun County, AL        1015  2017      2017   1338
